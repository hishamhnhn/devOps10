# %%
# import lab
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('ML-reg.csv')

# %%
df.head()
# Out:
#     age  distance  YearsExperience  Salary
# 0  31.1     77.75              1.1   39343
# 1  31.3     78.25              1.3   46205
# 2  31.5     78.75              1.5   37731
# 3  32.0     80.00              2.0   43525
# 4  32.2     80.50              2.2   39891

# %% [markdown]
# # feature extraction

# %%
x = df [['age','distance','YearsExperience']]
y = df['Salary']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
model = LinearRegression().fit(x_train,y_train)
model
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-7.23472174e+15, -2.16813894e+14,  7.77675648e+15])

# %%
model.intercept_
# Out:
# 2.3330269435026387e+17

# %%
model.predict(x_test)
# Out:
# array([ 40768., 122752.,  64960.,  63104., 115200., 107776.])

# %%
model.score(x_test,y_test)
# Out:
# 0.9881121259003347

# %% [markdown]
# # how plot multiple regesssion plot

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train['age'],x_train['distance'],x_train['YearsExperience'],y_train)
plt.plot(x_train, model.predict(x_train), color="Green")
plt.xlabel("years")
plt.ylabel('salary')
plt.title('train plot')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x_train['age']
# Out:
# 27    39.6
# 11    34.0
# 17    35.3
# 22    37.9
# 5     32.9
# 16    35.1
# 8     33.2
# 14    34.5
# 23    38.2
# 20    36.8
# 1     31.3
# 29    40.5
# 6     33.0
# 4     32.2
# 18    35.9
# 19    36.0
# 9     33.7
# 7     33.2
# 25    39.0
# 3     32.0
# 0     31.1
# 21    37.1
# 15    34.9
# 12    34.0
# Name: age, dtype: float64

# %%
y.shape
# Out:
# (30,)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_wireframe(x_train,model.predict(x_train), color='black')
ax.set_title('wireframe');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-abc1894a19b6> in <module>
#       1 fig = plt.figure()
#       2 ax = plt.axes(projection='3d')
# ----> 3 ax.plot_wireframe(x_train,model.predict(x_train), color='black')
#       4 ax.set_title('wireframe');
#
# TypeError: plot_wireframe() missing 1 required positional argument: 'Z'

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_train['age'],x_train['distance'],y_train,c='green', marker='o', alpha=0.5)
#ax.plot_surface(x_surf,y_surf,fittedY.reshape(x_surf.shape), color='b', alpha=0.3)
ax.set_xlabel('age')
ax.set_ylabel('distace')
ax.set_zlabel('salary')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(x_train['age'],x_train['distance'],model.predict(x_train),c='green', marker='o', alpha=0.5) 
#plot(x_train, model.predict(x_train), color="Green")
#ax.plot_surface(x_surf,y_surf,fittedY.reshape(x_surf.shape), color='b', alpha=0.3)
ax.set_xlabel('age')
ax.set_ylabel('distace')
ax.set_zlabel('salary')
plt.show()
